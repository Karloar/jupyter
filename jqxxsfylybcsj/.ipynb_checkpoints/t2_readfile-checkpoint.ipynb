# %%
from lxml import etree, html

# %%
path = '/Users/karloar/Documents/test.html'

# %%
content = open(path, 'rb').read()

# %%
page = html.document_fromstring(content)

# %%
text = page.text_content()

# %%
print(text)
# Out:
# 吉林大学考试通知单
#
#
# <!--table
# 	{mso-displayed-decimal-separator:"\.";
# 	mso-displayed-thousand-separator:"\,";}
# .font512210
# 	{color:windowtext;
# 	font-size:9.0pt;
# 	font-weight:400;
# 	font-style:normal;
# 	text-decoration:none;
# 	font-family:等线;
# 	mso-generic-font-family:auto;
# 	mso-font-charset:134;}
# .xl1512210
# 	{padding-top:1px;
# 	padding-right:1px;
# 	padding-left:1px;
# 	mso-ignore:padding;
# 	color:black;
# 	font-size:11.0pt;
# 	font-weight:400;
# 	font-style:normal;
# 	text-decoration:none;
# 	font-family:等线;
# 	mso-generic-font-family:auto;
# 	mso-font-charset:134;
# 	mso-number-format:General;
# 	text-align:general;
# 	vertical-align:bottom;
# 	mso-background-source:auto;
# 	mso-pattern:auto;
# 	white-space:nowrap;}
# .xl6312210
# 	{padding-top:1px;
# 	padding-right:1px;
# 	padding-left:1px;
# 	mso-ignore:padding;
# 	color:black;
# 	font-size:11.0pt;
# 	font-weight:400;
# 	font-style:normal;
# 	text-decoration:none;
# 	font-family:等线;
# ...
